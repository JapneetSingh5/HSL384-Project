# %%
import pandas as pd
gender = pd.read_csv('gender.csv')
df = pd.read_csv('hot100_cleaned.csv')
# Out:
# /var/folders/lk/c66jcxc517j4m73kkh93rvwr0000gn/T/ipykernel_51687/4015419353.py:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   gender = pd.read_csv('gender.csv')

# %%
df
# Out:
#                           title                              artist  year
# 0            A Big Hunk O' Love  Elvis Presley With The Jordanaires  1959
# 1             Come Softly To Me                      The Fleetwoods  1959
# 2      Heartaches By The Number                        Guy Mitchell  1959
# 3                   Kansas City                    Wilbert Harrison  1959
# 4                    Lonely Boy                           Paul Anka  1959
# ...                         ...                                 ...   ...
# 30012      Colombia, Mi Encanto                        Carlos Vives  2022
# 30013                 Down Home                        Jimmie Allen  2022
# 30014                Euthanasia                         Post Malone  2022
# 30015           Praise The Lord      BRELAND Featuring Thomas Rhett  2022
# 30016                   Sin Fin    Romeo Santos & Justin Timberlake  2022
#
# [30017 rows x 3 columns]

# %%
gender
# Out:
#         chartmetric_id                  name artist_country    pronoun  \
# 0                    1       various artists             GB  they/them
# 1                    2        massive attack             GB  they/them
# 2                    3  squirrel nut zippers             US  they/them
# 3                    4             bob dylan             US     he/him
# 4                    5                  10cc             GB  they/them
# ...                ...                   ...            ...        ...
# 687137         9575811             zero dark             US  they/them
# 687138         9580415           phil walker            NaN     he/him
# 687139         9593090                blexon            NaN     he/him
# 687140         9607375          darren kiely            NaN     he/him
# 687141         9623804           erika edgar            NaN    she/her
#
#         gender is_band                                              genre
# ...

# %%
df_dict = df.to_dict('records')
gender_dict = gender.to_dict('index')

# %%
len_df = len(df_dict)
print(len_df)
# Out:
# 30017

# %%
gender
# Out:
#         chartmetric_id                  name artist_country    pronoun  \
# 0                    1       Various Artists             GB  they/them
# 1                    2        Massive Attack             GB  they/them
# 2                    3  Squirrel Nut Zippers             US  they/them
# 3                    4             Bob Dylan             US     he/him
# 4                    5                  10cc             GB  they/them
# ...                ...                   ...            ...        ...
# 687137         9575811             Zero Dark             US  they/them
# 687138         9580415           Phil Walker            NaN     he/him
# 687139         9593090                Blexon            NaN     he/him
# 687140         9607375          Darren Kiely            NaN     he/him
# 687141         9623804           Erika Edgar            NaN    she/her
#
#         gender is_band                                              genre
# ...

# %%
gender['name'] =gender['name'].str.lower()
df['artist'] =df['artist'].str.lower()
gender.drop_duplicates(subset=['name'],inplace=True)
gender
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
#         chartmetric_id                  name artist_country    pronoun  \
# 0                    1       various artists             GB  they/them
# 1                    2        massive attack             GB  they/them
# 2                    3  squirrel nut zippers             US  they/them
# 3                    4             bob dylan             US     he/him
# 4                    5                  10cc             GB  they/them
# ...                ...                   ...            ...        ...
# 687137         9575811             zero dark             US  they/them
# 687138         9580415           phil walker            NaN     he/him
# 687139         9593090                blexon            NaN     he/him
# 687140         9607375          darren kiely            NaN     he/him
# ...

# %%
df = df.merge(gender, left_on='artist', right_on='name', how='left')
df
df['artist_country'].unique()
# Out:
# array([nan, 'US', 'CA', 'DE', 'ES', 'IE', 'UY', 'SE', 'FR', 'MX', 'EG',
#        'JM', 'GB', 'AU', 'IT', 'BR', 'NL', 'ZA', 'JP', 'FK', 'GH', 'PH',
#        'NZ', 'CH', 'MC', 'CN', 'AT', 'CU', 'AR', 'CZ', 'BE', 'LB', 'EE',
#        'KR', 'BS', 'NO', 'BB', 'BO', 'HU', 'MY', 'UG', 'CM', 'GE', 'FI',
#        'HK', 'PL', 'CO', 'VE', 'SI', 'MA', 'GR', 'RS', 'RU', 'MN', 'RW',
#        'ID', 'CL', 'DK', 'PR', 'SO', 'TR', 'NG', 'RO', 'TT', 'KZ', 'IN',
#        'DO', 'TD', 'PA', 'VG', 'HT', 'SN', 'IS', 'TN', 'IL', 'PE', 'AM'],
#       dtype=object)

# %%
df[['pronoun','gender']].count()
# Out:
# pronoun    22544
# gender      7533
# dtype: int64

# %%
df['pronoun'].isnan().count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/japneet/Desktop/HSL384-/Untitled.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/japneet/Desktop/HSL384-/Untitled.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> df['pronoun'].isnan().count()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'isnan'

# %%
df['pronoun'].isna().sum()
df['gender'].isna().sum()
# Out:
# 22484

# %%
df[['pronoun','gender']].value_counts()
# Out:
# pronoun            gender
# he/him             male                 3585
# they/them          male                 1845
# she/her            female               1399
# they/them          mixed                 501
#                    female                127
# they/them/she/her  non-binary             23
# she/her            genderfluid            22
# they/them          non-binary             12
# she/they           female                 10
#                    genderqueer             4
# she/her            androgynous             3
#                    transgender woman       1
# she/they           non-binary              1
# dtype: int64

# %%
df
# Out:
#                           title                              artist  year  \
# 0            A Big Hunk O' Love  elvis presley with the jordanaires  1959
# 1             Come Softly To Me                      the fleetwoods  1959
# 2      Heartaches By The Number                        guy mitchell  1959
# 3                   Kansas City                    wilbert harrison  1959
# 4                    Lonely Boy                           paul anka  1959
# ...                         ...                                 ...   ...
# 30012      Colombia, Mi Encanto                        carlos vives  2022
# 30013                 Down Home                        jimmie allen  2022
# 30014                Euthanasia                         post malone  2022
# 30015           Praise The Lord      breland featuring thomas rhett  2022
# 30016                   Sin Fin    romeo santos & justin timberlake  2022
#
#        chartmetric_id_x            name_x artist_country_x  pronoun_x  \
# ...

# %%
df.to_csv('artist_gender_joined.csv')

# %%
lyrics = pd.read_csv('song_lyrics_missing_scraped_iter2.csv')

# %%
print(lyrics['Lyrics'].isna().sum())
# Out:
# 3433

# %%
lyrics['Lyrics'].tail()
# Out:
# 30016    Colombia  Mi Encanto Lyrics[Letra de  Colombia...
# 30017    ​down home Lyrics[Verse 1] I bet you're up the...
# 30018    Euthanasia Lyrics[Verse 1] Took a fuckin' sip ...
# 30019                                                  NaN
# 30020                                                  NaN
# Name: Lyrics, dtype: object

# %%
df
# Out:
#                           title                              artist  year  \
# 0            A Big Hunk O' Love  elvis presley with the jordanaires  1959
# 1             Come Softly To Me                      the fleetwoods  1959
# 2      Heartaches By The Number                        guy mitchell  1959
# 3                   Kansas City                    wilbert harrison  1959
# 4                    Lonely Boy                           paul anka  1959
# ...                         ...                                 ...   ...
# 30012      Colombia, Mi Encanto                        carlos vives  2022
# 30013                 Down Home                        jimmie allen  2022
# 30014                Euthanasia                         post malone  2022
# 30015           Praise The Lord      breland featuring thomas rhett  2022
# 30016                   Sin Fin    romeo santos & justin timberlake  2022
#
#        chartmetric_id_x            name_x artist_country_x  pronoun_x  \
# ...

# %%
origins = df[['artist', 'artist_country_x']]
origins.to_csv('origin.csv')
